# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Pakapak Silpapinun** <br>
# I want to be a machine learning engineer

# %% [markdown]
# *I am interested in data science because my desired career needs to handle lots of data. In order to enhance my ability and prepare myself, I think I need to learn about data science.*

# %% [markdown]
# I am going to plot the simple sine wave.

# %%
import numpy as np
from matplotlib import pyplot as plt
t = np.arange(0,100, 0.01)
y = np.sin(t)

plt.plot(t,y)
plt.title("sine wave")
plt.grid(1)
plt.show()

# %% [markdown]
# <p> horizontal rule</p>
# <hr>
#
# <p>bullet list </p>
# <ul>
#     <li>a</li>
#     <li>b</li>
#     <li>c</li>
# </ul>
#
# <p>numbered list</p>
# <ol>
#     <li>a</li>
#     <li>b</li>
#     <li>c</li>
# </ol>
#
# <p>table</p>
# <table>
#     <tr>
#         <th>col1</th>
#         <th>col2</th>
#     </tr>
#     <tr>
#         <td>data1</td>
#         <td>data2</td>
#     </tr>
# </table>
